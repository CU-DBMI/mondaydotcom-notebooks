# %% [markdown]
# # Create Monthly Task Reports in Smartsheet
#
# Takes records from MDC and creates a JSON object for later reporting.

# %%
#%load_ext nb_black

# %%
import os
import json
import logging
from datetime import datetime, timedelta
from dateutil import parser
from typing import Dict, List
from pprint import pprint
import pandas as pd
import numpy as np
from pathlib import Path
import smartsheet

# uses the pretty okay SDK here: https://github.com/ProdPerfect/monday
from monday import MondayClient

from mondaydotcom_utils.formatted_value import (
    FormattedValue,
    get_col_defs,
    get_items_by_board,
)

import scrapbook as sb
import dotenv

from jsonschema import validate, ValidationError, RefResolver
from jsonschema.exceptions import RefResolutionError

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
# MDC boards
TASKS_BOARD_ID = "1883170887"
AGREEMENTS_BOARD_ID = "1882423671"
PROJECTS_BOARD_ID = "1882404316"
ACCOUNTS_BOARD_ID = "1882424009"

# SS tables
posted_tasks_id = 3567675495475076

# %%
environment = "dev"

# change these or set as papermill parameters to report on year and month
year_for_report = 2021
month_for_report = 9

# if entering custom report notes
notes = ""

# it is possible to run this without posting to smartsheet... useful for testing
post_records = False

# filter for "ready" tasks
filter_tasks_by = "Posted"  # or also "Posted"

# %%
# check the environment vars for secrets

env_file = f".env-{environment}"
logger.info("Loading the .env file from %s", env_file)
dotenv.load_dotenv(dotenv.find_dotenv(env_file))

assert os.environ.get("MONDAY_KEY"), f"MONDAY_KEY not found in {env_file}"
assert os.environ.get("SMARTSHEET_KEY"), f"SMARTSHEET_KEY not found in {env_file}"

# %%
# connect monday client
conn = MondayClient(os.environ.get("MONDAY_KEY"))

# %%
# connect smartsheet client
ss_client = smartsheet.Smartsheet(os.environ.get("SMARTSHEET_KEY"))
ss_client.errors_as_exceptions(True)

# %%
def month_end_date(year, month):
    """Calculate the month end date given a year and month."""
    month += 1
    if month == 13:
        month = 1
        year += 1

    tempdate = datetime.strptime(f"{year}-{month}-1", "%Y-%m-%d")
    return (tempdate - timedelta(days=1)).strftime("%Y-%m-%d")

# %%
month_ending_date = month_end_date(year_for_report, month_for_report)
month_ending_date
# Out:
# '2021-09-30'

# %%
prepared_date = datetime.today().strftime("%Y-%m-%d")
prepared_date
# Out:
# '2022-07-05'

# %%
# bug between ProdPerfect and MDC's API: https://github.com/ProdPerfect/monday/issues/57
from monday.resources.base import BaseResource

query = """query
    {
        users () {
            id
            name
            email
            enabled
        }
    }"""
query
# Out:
# 'query\n    {\n        users () {\n            id\n            name\n            email\n            enabled\n        }\n    }'

# %%
base_resource = BaseResource(os.environ.get("MONDAY_KEY"))
users = base_resource._query(query)["data"]["users"]

# %%
users_df = pd.DataFrame(users).set_index("id")
users_df.head()
# Out:
#                         name                              email  enabled
# id
# 25810257        Steve Taylor      stephen.taylor@cuanschutz.edu     True
# 25815853  Faisal Alquaddoomi  faisal.alquaddoomi@cuanschutz.edu     True
# 25815860   Vincent Rubinetti   vincent.rubinetti@cuanschutz.edu     True
# 26327954          Audrey Wen          audrey.wen@cuanschutz.edu     True
# 28137107       Holly Heilman       holly.heilman@cuanschutz.edu     True

# %%
accounts_df = get_items_by_board(conn, ACCOUNTS_BOARD_ID).fillna("")

accounts_df.rename(
    columns={
        "monday_id": "MDC Client ID",
        "monday_name": "Client Name",
        "No Bill__checked": "No Bill",
        "Notes": "Client Notes",
    },
    inplace=True,
)

accounts_df.drop(
    columns=[
        "Contacts",
        "Subitems",
        "Customer Projects",
        "No Bill__changed_at",
        "Type__text",
        "Type__changed_at",
    ],
    inplace=True,
)

accounts_df
# Out:
#     MDC Client ID                                        Client Name  \
# 0      1882439999                       HealthAI: Admin & Operations
# 1      1883644776                              HealthAI: Bennett Lab
# 2      1882681138                               HealthAI: Greene Lab
# 3      1883648098                               HealthAI: Hunter Lab
# 4      1882681714                                   HealthAI: TISLab
# 5      1883649981                                  HealthAI: Way Lab
# 6      1882462147                              CU SOM: IT Department
# 7      1882588856      CIDA: Center for Innovative Design & Analysis
# 8      1907269862                               HealthAI: Sean Davis
# 9      2246385174                                HealthAI: Dwork Lab
# 10     2335036392    CCPM: Colorado Center for Personalized Medicine
# 11     2335047997            CRIO: Chief Research Informatics Office
# 12     2335055048  CeDAR: Center for Dependency, Addiction and Re...
# 13     2721260623                                        Foster Goss
#
#                                          Client Notes  No Bill
# 0   A catch-all account for any work we do for Aud...     True
# 1                                                        False
# 2                                                        False
# 3                                                        False
# 4                                                        False
# 5                                                        False
# 6                                                        False
# 7                                                        False
# 8                                                        False
# 9                                                        False
# 10                                                       False
# 11                                                       False
# 12                                                       False
# 13                   Potential project for EKG ML app    False

# %%
projects_df = get_items_by_board(conn, PROJECTS_BOARD_ID).fillna("")

projects_df.rename(
    columns={
        "monday_id": "MDC Project ID",
        "monday_name": "Project Name",
        "Project Lifecycle__text": "Project Lifecycle",
        "Account": "MDC Client ID",
        "Notes": "Project Notes",
    },
    inplace=True,
)

projects_df.drop(
    columns=[
        "Project Tasks",
        "Subitems",
        "Project Contacts",
        "Timeline",
        "Customer Source",
        "Dependency",
        "Date Added",
        "Timeline Days",
        "Date Added__default_formatter",
        "Tasks Status__mirror",
        "Project Lifecycle__changed_at",
        "Repo Description__mirror",
        "Timeline__to",
        "Timeline__from",
        "Timeline__changed_at",
    ],
    inplace=True,
)

projects_df = projects_df.explode(["MDC Client ID"], ignore_index=True)
projects_df
# Out:
#     MDC Project ID                                       Project Name  \
# 0       1888314634                  CHAI: Admin Technology Foundation
# 1       2208602434                        CHAI: Department Financials
# 2       2303312548                    TISLab: Staffing/Support FY2022
# 3       2303324267                 Greenelab: Staffing/Support FY2022
# 4       2334955423                   Way Lab: Staffing/Support FY2022
# 5       1882738595                          Greenelab: mygeneset.info
# 6       2831164270                 CHAI: CY2022 Prof. Dev. Goal/Tasks
# 7       1882739627                             CHAI: Manubot next-gen
# 8       2249818009             TISLab: Monarch UI (3.0) Extended 2022
# 9       2265215456                         Way: pyctytominer (Python)
# 10      2269226607             CHAI: Center/Department Reviews CY2021
# 11      1977980999                Greenelab: Preprint Single Page App
# 12      1957293587                                 Way: Grant Support
# 13      1882913862                          TISLab: Graph DB Deployer
# 14      1892630899                      TISLab: Monarch GCP migration
# 15      1883134208                    CHAI: Config Monday.com for SET
# 16      1882712838  Greenelab: lab-website-template and related si...
# 17      1882752029                      HealthAI "lab" Portfolio Site
# 18      1890624311                         Center software guidelines
# 19      1882442059                  TISLab: Monarch UI (3.0) Redesign
# 20      1969468997  Greenelab: Biomedical Literature "Word Lapse" ...
#
#    Project Lifecycle MDC Client ID Grant Number  \
# 0               Open    1882439999
# 1               Open    1882439999
# 2               Open    1882681714
# 3               Open    1882681138
# 4               Open    1883649981
# 5               Open    1882681138
# 6               Open    1882439999
# 7                       1882439999       213269
# 8                       1882681714
# 9                       1883649981       221151
# 10            Closed    1882439999
# 11            Closed    1882681138
# 12            Closed    1883649981
# 13            Closed    1882681714
# 14            Closed    1882681714
# 15            Closed    1882439999
# 16            Closed    1882681138
# 17            Closed    1882439999
# 18            Closed    1882439999
# 19            Closed    1882681714       213359
# 20            Closed    1882681138       213269
#
#                                         Project Notes Project Closed Date
# 0
# 1
# 2                     General non-grant staff support
# 3                     General non-grant staff support
# 4                     General non-grant staff support
# 5   Collaboration with BioThings organization. Web...
# 6   For tracking tasks against professional develo...
# 7   Pending scoping and schedule; Issue resolution...
# 8   Pending: Enhancements and extended Monarch UI ...          2022-05-12
# 9                   Pending: Python and build support
# 10                                             Closed          2022-03-21
# 11                                             Closed
# 12                                             Closed
# 13                                             Closed          2021-12-16
# 14                                             Closed          2022-03-30
# 15                                                             2021-11-26
# 16  Bucket of hours for maintaining Jekyll website...          2022-04-06
# 17  Exhibition and brochure of our (center softwar...          2022-04-28
# 18  Preferred tools, workflows, methodologies, phi...          2022-04-05
# 19  Was managed and tracked via github and zenhub;...          2022-05-25
# 20  Similar in scope and size to https://greenelab...          2022-06-21

# %%
# add the account to the projects
account_projects_df = pd.merge(projects_df, accounts_df, how="left", on="MDC Client ID")
account_projects_df
# Out:
#     MDC Project ID                                       Project Name  \
# 0       1888314634                  CHAI: Admin Technology Foundation
# 1       2208602434                        CHAI: Department Financials
# 2       2303312548                    TISLab: Staffing/Support FY2022
# 3       2303324267                 Greenelab: Staffing/Support FY2022
# 4       2334955423                   Way Lab: Staffing/Support FY2022
# 5       1882738595                          Greenelab: mygeneset.info
# 6       2831164270                 CHAI: CY2022 Prof. Dev. Goal/Tasks
# 7       1882739627                             CHAI: Manubot next-gen
# 8       2249818009             TISLab: Monarch UI (3.0) Extended 2022
# 9       2265215456                         Way: pyctytominer (Python)
# 10      2269226607             CHAI: Center/Department Reviews CY2021
# 11      1977980999                Greenelab: Preprint Single Page App
# 12      1957293587                                 Way: Grant Support
# 13      1882913862                          TISLab: Graph DB Deployer
# 14      1892630899                      TISLab: Monarch GCP migration
# 15      1883134208                    CHAI: Config Monday.com for SET
# 16      1882712838  Greenelab: lab-website-template and related si...
# 17      1882752029                      HealthAI "lab" Portfolio Site
# 18      1890624311                         Center software guidelines
# 19      1882442059                  TISLab: Monarch UI (3.0) Redesign
# 20      1969468997  Greenelab: Biomedical Literature "Word Lapse" ...
#
#    Project Lifecycle MDC Client ID Grant Number  \
# 0               Open    1882439999
# 1               Open    1882439999
# 2               Open    1882681714
# 3               Open    1882681138
# 4               Open    1883649981
# 5               Open    1882681138
# 6               Open    1882439999
# 7                       1882439999       213269
# 8                       1882681714
# 9                       1883649981       221151
# 10            Closed    1882439999
# 11            Closed    1882681138
# 12            Closed    1883649981
# 13            Closed    1882681714
# 14            Closed    1882681714
# 15            Closed    1882439999
# 16            Closed    1882681138
# 17            Closed    1882439999
# 18            Closed    1882439999
# 19            Closed    1882681714       213359
# 20            Closed    1882681138       213269
#
#                                         Project Notes Project Closed Date  \
# 0
# 1
# 2                     General non-grant staff support
# 3                     General non-grant staff support
# 4                     General non-grant staff support
# 5   Collaboration with BioThings organization. Web...
# 6   For tracking tasks against professional develo...
# 7   Pending scoping and schedule; Issue resolution...
# 8   Pending: Enhancements and extended Monarch UI ...          2022-05-12
# 9                   Pending: Python and build support
# 10                                             Closed          2022-03-21
# 11                                             Closed
# 12                                             Closed
# 13                                             Closed          2021-12-16
# 14                                             Closed          2022-03-30
# 15                                                             2021-11-26
# 16  Bucket of hours for maintaining Jekyll website...          2022-04-06
# 17  Exhibition and brochure of our (center softwar...          2022-04-28
# 18  Preferred tools, workflows, methodologies, phi...          2022-04-05
# 19  Was managed and tracked via github and zenhub;...          2022-05-25
# 20  Similar in scope and size to https://greenelab...          2022-06-21
#
#                      Client Name  \
# 0   HealthAI: Admin & Operations
# 1   HealthAI: Admin & Operations
# 2               HealthAI: TISLab
# 3           HealthAI: Greene Lab
# 4              HealthAI: Way Lab
# 5           HealthAI: Greene Lab
# 6   HealthAI: Admin & Operations
# 7   HealthAI: Admin & Operations
# 8               HealthAI: TISLab
# 9              HealthAI: Way Lab
# 10  HealthAI: Admin & Operations
# 11          HealthAI: Greene Lab
# 12             HealthAI: Way Lab
# 13              HealthAI: TISLab
# 14              HealthAI: TISLab
# 15  HealthAI: Admin & Operations
# 16          HealthAI: Greene Lab
# 17  HealthAI: Admin & Operations
# 18  HealthAI: Admin & Operations
# 19              HealthAI: TISLab
# 20          HealthAI: Greene Lab
#
#                                          Client Notes  No Bill
# 0   A catch-all account for any work we do for Aud...     True
# 1   A catch-all account for any work we do for Aud...     True
# 2                                                        False
# 3                                                        False
# 4                                                        False
# 5                                                        False
# 6   A catch-all account for any work we do for Aud...     True
# 7   A catch-all account for any work we do for Aud...     True
# 8                                                        False
# 9                                                        False
# 10  A catch-all account for any work we do for Aud...     True
# 11                                                       False
# 12                                                       False
# 13                                                       False
# 14                                                       False
# 15  A catch-all account for any work we do for Aud...     True
# 16                                                       False
# 17  A catch-all account for any work we do for Aud...     True
# 18  A catch-all account for any work we do for Aud...     True
# 19                                                       False
# 20                                                       False

# %%
# only getting done tasks
tasks_df = get_items_by_board(conn, TASKS_BOARD_ID, "status", "Done")

# Only include Ready tasks
if filter_tasks_by == "Ready":
    tasks_df = tasks_df.loc[
        tasks_df["Integration Message"].str.startswith("Ready", na=False)
    ]
elif filter_tasks_by == "Posted":
    # had to add this to redo the old stuff into a new json format
    tasks_df = tasks_df.loc[
        tasks_df["Integration Message"].str.startswith("Posted", na=False)
    ]
else:
    # don't filter at all
    pass

tasks_df.rename(
    columns={
        "monday_id": "MDC Task ID",
        "monday_name": "Task Name",
        "Customer Project": "MDC Project ID",
        "Notes": "Task Notes",
    },
    inplace=True,
)

tasks_df.drop(
    columns=[
        "Subtasks",
        "Customer Repos",
        "Timeline Hours (Estimated)__formula",
        "Timeline__visualization_type",
        "Actual Time__running",
        "Timeline__to",
        "Timeline__from",
        "Timeline__changed_at",
        "Timeline Days",
        "Total Actual Hours__formula",
        "Date Added__default_formatter",
        "Timeline",
        "Actual Time__startDate",
        "Actual Time__changed_at",
        "Actual Time",
        "Date Added",
        "Dependencies",
        "Project Status__mirror",
        "Project Closed Date__mirror",
    ],
    inplace=True,
)

tasks_df = tasks_df.explode(["MDC Project ID"], ignore_index=True)
tasks_df.head()
# Out:
#    MDC Task ID                                          Task Name  \
# 0   1906313744  Lab Website Template v0.5 accessibility, perfo...
# 1   1906337176  Preprint Similarity Search app maintenance and...
# 2   1906376074                          Implement modal component
# 3   1912542060                     Patch AWS (or remove entirely)
# 4   1916012594                       graphdb-deployer development
#
#   MDC Project ID                                 Owner Status__text  \
# 0     1882712838  [{'id': 25815860, 'kind': 'person'}]         Done
# 1     1977980999  [{'id': 25815860, 'kind': 'person'}]         Done
# 2     1882442059  [{'id': 25815860, 'kind': 'person'}]         Done
# 3     2303324267  [{'id': 25810257, 'kind': 'person'}]         Done
# 4     1882913862  [{'id': 25815853, 'kind': 'person'}]         Done
#
#          Status__changed_at                  Integration Message  \
# 0  2021-11-15T17:07:34.444Z  Posted - 2022-04-27 16:39:08.404092
# 1  2021-11-15T17:11:18.983Z  Posted - 2022-04-27 16:39:12.590458
# 2  2021-11-17T22:13:28.278Z  Posted - 2022-04-27 16:39:14.913360
# 3  2022-01-25T21:59:56.747Z  Posted - 2022-04-27 16:44:52.850435
# 4  2022-01-26T17:31:13.547Z  Posted - 2022-04-27 16:45:11.015272
#
#    Actual Time__duration                      Actual Time__additional_value  \
# 0                64800.0  [{'id': 150436869, 'account_id': 10368903, 'pr...
# 1                18000.0  [{'id': 150439621, 'account_id': 10368903, 'pr...
# 2                15505.0  [{'id': 150443741, 'account_id': 10368903, 'pr...
# 3                    NaN                                                NaN
# 4                69548.0  [{'id': 159439810, 'account_id': 10368903, 'pr...
#
#    Actual Hours                                         Task Notes  \
# 0           NaN                                               None
# 1           NaN                                               None
# 2           NaN  https://github.com/monarch-initiative/monarch-...
# 3           2.0  Time spent reviewing options; finally decided ...
# 4           NaN  includes initial setup, testing w/kevin, gener...
#
#   Pull Request URL Issue URL Date Completed Extended Hours  \
# 0             None      None     2021-11-19           None
# 1             None      None     2021-11-17           None
# 2             None      None     2021-11-23           None
# 3             None      None     2022-01-25           None
# 4             None      None     2022-01-07           None
#
#   Reported Month-end Date
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None

# %% [markdown]
# Validate takes an individual record and checks it against rules, and creates multiple task records where required.
#
# If actual hours is used, then the number of owners dictates the number of journal records. E.g., actual hours = 15, with 3 owners, yields three journal entries at 5 each (actual hours / owner count).

# %%
records = tasks_df.to_dict(orient="records")

# %%
# check for actual hours records
owner_records = []

for record in records:

    actual_hours = record["Actual Hours"]
    owners_list = record["Owner"] if isinstance(record["Owner"], list) else []
    len_owners_list = len(owners_list)
    date_completed = record["Date Completed"]

    if not np.isnan(actual_hours):
        # split the hours up between the owners
        for owner in owners_list:
            new_rec = record.copy()

            # overwrite the owner
            new_rec["MDC Resource ID"] = owner["id"]
            new_rec["Resource Name"] = users_df.loc[owner["id"]]["name"]

            # divide the task time
            new_rec["hours"] = actual_hours / len_owners_list

            # get the task time from date completed... or fallback on the status
            if record.get("Date Completed") and record["Date Completed"]:
                new_rec["Session Completed"] = parser.parse(
                    f"{date_completed}"
                ).strftime("%Y-%m-%d")
            else:
                new_rec["Session Completed"] = parser.parse(
                    record["Status__changed_at"]
                ).strftime("%Y-%m-%d")

            new_rec["integration_state_rule"] = "hours_split_between_owners"
            owner_records.append(new_rec)

# %%
owner_records_df = pd.DataFrame(owner_records)
owner_records_df.drop(
    columns=[
        "Actual Time__additional_value",
        "Actual Time__duration",
        "Status__changed_at",
        "Actual Hours",
    ],
    inplace=True,
)
owner_records_df.rename(columns={"Status__text": "Status"}, inplace=True)
owner_records_df
# Out:
#     MDC Task ID                                          Task Name  \
# 0    1912542060                     Patch AWS (or remove entirely)
# 1    1957499412         Way Lab Grant Proposal Creation and Review
# 2    1957499412         Way Lab Grant Proposal Creation and Review
# 3    2003198974          "Word Lapse" Proposal Creation and Review
# 4    2064112158        monarch blue/green data migration, research
# ..          ...                                                ...
# 59   2512879308         chai website updates, meetings, pr reviews
# 60   2516729878  incorporate 3rd party reactome viewer and geno...
# 61   2618506907  3rd-party monday.com API has rate-limiting blo...
# 62   2627157922  Coursera: Researcher Management and Leadership...
# 63   2670960378  Potential memory leak in SingleCell's .merge_s...
#
#     MDC Project ID                                              Owner Status  \
# 0       2303324267               [{'id': 25810257, 'kind': 'person'}]   Done
# 1       1957293587  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 2       1957293587  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 3       1969468997               [{'id': 25810257, 'kind': 'person'}]   Done
# 4       1892630899               [{'id': 25815853, 'kind': 'person'}]   Done
# ..             ...                                                ...    ...
# 59      1888314634               [{'id': 25815860, 'kind': 'person'}]   Done
# 60      1882442059               [{'id': 25815860, 'kind': 'person'}]   Done
# 61      2208602434               [{'id': 25810257, 'kind': 'person'}]   Done
# 62      2831164270               [{'id': 29667633, 'kind': 'person'}]   Done
# 63      2334955423               [{'id': 29667633, 'kind': 'person'}]   Done
#
#                               Integration Message  \
# 0             Posted - 2022-04-27 16:44:52.850435
# 1             Posted - 2022-04-27 16:42:44.753809
# 2             Posted - 2022-04-27 16:42:44.753809
# 3             Posted - 2022-04-27 16:42:47.060917
# 4             Posted - 2022-04-27 16:47:42.940380
# ..                                            ...
# 59  Posted - No Bill - 2022-05-05 11:51:17.461770
# 60            Posted - 2022-06-02 08:19:42.042905
# 61  Posted - No Bill - 2022-06-02 08:19:42.830261
# 62  Posted - No Bill - 2022-06-02 08:19:43.721551
# 63            Posted - 2022-06-02 08:19:45.571153
#
#                                            Task Notes Pull Request URL  \
# 0   Time spent reviewing options; finally decided ...             None
# 1                                                None             None
# 2                                                None             None
# 3   200 hour proposal sent to Casey and David, 12/...             None
# 4                                                None             None
# ..                                                ...              ...
# 59          * imported from SmartSheets records [sjt]             None
# 60  Captured in extended and new phases of work. D...             None
# 61  The ProdPerfect monday.com API library is pass...             None
# 62  Learning CU Anschutz and broader research proc...             None
# 63  Issue created additional more focused issues w...             None
#
#                                             Issue URL Date Completed  \
# 0                                                None     2022-01-25
# 1                                                None     2021-12-04
# 2                                                None     2021-12-04
# 3                                                None     2021-12-04
# 4                                                None     2022-02-23
# ..                                                ...            ...
# 59                                               None     2021-10-20
# 60                                               None     2022-05-25
# 61    https://github.com/ProdPerfect/monday/issues/57     2022-05-04
# 62                                               None     2022-05-12
# 63  https://github.com/cytomining/pycytominer/issu...     2022-05-25
#
#    Extended Hours Reported Month-end Date  MDC Resource ID  \
# 0            None                    None         25810257
# 1            None                    None         25810257
# 2            None                    None         25815853
# 3            None                    None         25810257
# 4            None                    None         25815853
# ..            ...                     ...              ...
# 59           None                    None         25815860
# 60           None                    None         25815860
# 61           None                    None         25810257
# 62           None                    None         29667633
# 63           None                    None         29667633
#
#          Resource Name  hours Session Completed      integration_state_rule
# 0         Steve Taylor    2.0        2022-01-25  hours_split_between_owners
# 1         Steve Taylor    2.0        2021-12-04  hours_split_between_owners
# 2   Faisal Alquaddoomi    2.0        2021-12-04  hours_split_between_owners
# 3         Steve Taylor    2.0        2021-12-04  hours_split_between_owners
# 4   Faisal Alquaddoomi   28.0        2022-02-23  hours_split_between_owners
# ..                 ...    ...               ...                         ...
# 59   Vincent Rubinetti    8.0        2021-10-20  hours_split_between_owners
# 60   Vincent Rubinetti    0.0        2022-05-25  hours_split_between_owners
# 61        Steve Taylor    4.0        2022-05-04  hours_split_between_owners
# 62         Dave Bunten   24.0        2022-05-12  hours_split_between_owners
# 63         Dave Bunten   16.0        2022-05-25  hours_split_between_owners
#
# [64 rows x 17 columns]

# %% [markdown]
# A Task in MDC can track work done in 'sessions' anyone can create a session on a Task, even one "owned" by someone else. This doesn't happen often here, but the following breaks out the sessions as separate task records.

# %%
# run through the records, looking for sessions, and if found,
# create new journal tasks for each one
session_records = []

for record in records:

    if isinstance(record["Actual Time__additional_value"], list):
        sessions_list = record["Actual Time__additional_value"]
    else:
        sessions_list = []

    actual_hours = record["Actual Time__duration"] / 60 / 60

    i = 1
    # multiply the number of tasks by sessions
    for session in sessions_list:
        new_rec = record.copy()

        new_rec["MDC Resource ID"] = session["ended_user_id"]
        new_rec["Resource Name"] = users_df.loc[session["ended_user_id"]]["name"]

        start_date = parser.parse(session["started_at"])
        end_date = parser.parse(session["ended_at"])
        new_rec["Session Completed"] = end_date.strftime("%Y-%m-%d")

        # take the difference between the two dates as hours
        difference = end_date - start_date
        new_rec["hours"] = difference.total_seconds() / 60 / 60

        # show each task ID with an index
        new_rec["MDC Task ID"] = f"{record['MDC Task ID']}-{i}"
        i = i + 1

    new_rec["integration_state_rule"] = "hours_from_session_records"
    session_records.append(new_rec)

session_records_df = pd.DataFrame(session_records)
session_records_df.drop(
    columns=[
        "Actual Time__additional_value",
        "Actual Time__duration",
        "Status__changed_at",
        "Actual Hours",
    ],
    inplace=True,
)
session_records_df.rename(columns={"Status__text": "Status"}, inplace=True)
session_records_df.sort_values(by="Task Name")
# Out:
#       MDC Task ID                                          Task Name  \
# 102  2512878891-2                 Accessibility research and reading
# 100  2512878852-1                 Add Center to zendesk website form
# 5    1916502641-4  Add api mocks to cypress, move from mock-adapt...
# 41   2251375853-3          Add build and PyPI publish to pycytominer
# 144  2571669338-3                                 CCPM GTC debugging
# ..            ...                                                ...
# 71   2366527256-5    updating backend to deal with new model changes
# 30   2249553502-4      word-lapse API: optimizing neighbors endpoint
# 93   2487370238-2                    word-lapse autocomplete support
# 94   2487376919-1             word-lapse caching server-side support
# 18   2106793452-5                 word-lapse pipeline and API server
#
#      MDC Project ID                                 Owner Status  \
# 102      1888314634  [{'id': 25815860, 'kind': 'person'}]   Done
# 100      1888314634  [{'id': 25810257, 'kind': 'person'}]   Done
# 5        1882442059  [{'id': 25815860, 'kind': 'person'}]   Done
# 41       2334955423  [{'id': 25810257, 'kind': 'person'}]   Done
# 144      1888314634  [{'id': 25815853, 'kind': 'person'}]   Done
# ..              ...                                   ...    ...
# 71       1969468997  [{'id': 25815853, 'kind': 'person'}]   Done
# 30       1969468997  [{'id': 25815853, 'kind': 'person'}]   Done
# 93       1969468997  [{'id': 25815853, 'kind': 'person'}]   Done
# 94       1969468997  [{'id': 25815853, 'kind': 'person'}]   Done
# 18       1969468997  [{'id': 25815853, 'kind': 'person'}]   Done
#
#                                Integration Message  \
# 102  Posted - No Bill - 2022-05-05 11:53:27.153605
# 100  Posted - No Bill - 2022-05-05 11:53:26.484196
# 5              Posted - 2022-04-27 16:42:35.471516
# 41             Posted - 2022-04-27 16:49:38.746731
# 144  Posted - No Bill - 2022-05-05 11:59:17.788244
# ..                                             ...
# 71             Posted - 2022-04-27 17:02:06.484784
# 30             Posted - 2022-04-27 16:49:17.192304
# 93             Posted - 2022-04-27 17:03:00.817252
# 94             Posted - 2022-04-27 17:03:02.759507
# 18             Posted - 2022-04-27 16:47:58.725284
#
#                                             Task Notes  \
# 102                                               None
# 100  Ticket submitted: https://medschool.zendesk.co...
# 5    https://github.com/monarch-initiative/monarch-...
# 41                                                None
# 144                                               None
# ..                                                 ...
# 71                                                None
# 30                                                None
# 93                                                None
# 94                                                None
# 18                                                None
#
#                                       Pull Request URL  \
# 102                                               None
# 100                                               None
# 5                                                 None
# 41   https://github.com/cytomining/pycytominer/pull...
# 144                                               None
# ..                                                 ...
# 71                                                None
# 30                                                None
# 93                                                None
# 94                                                None
# 18                                                None
#
#                                              Issue URL Date Completed  \
# 102                                               None     2021-11-19
# 100                                               None     2021-11-09
# 5                                                 None     2021-12-03
# 41                                                None     2022-02-08
# 144                                               None     2022-04-21
# ..                                                 ...            ...
# 71                                                None     2022-03-14
# 30                                                None     2022-02-23
# 93   https://github.com/greenelab/word-lapse/issues/27     2022-03-30
# 94                                                None     2022-03-30
# 18                                                None     2022-02-09
#
#     Extended Hours Reported Month-end Date  MDC Resource ID  \
# 102           None                    None         25815860
# 100           None                    None         25810257
# 5             None                    None         25815860
# 41            None                    None         25810257
# 144           None                    None         25815853
# ..             ...                     ...              ...
# 71            None                    None         25815853
# 30            None                    None         25815853
# 93            None                    None         25815853
# 94            None                    None         25815853
# 18            None                    None         25810257
#
#           Resource Name Session Completed  hours      integration_state_rule
# 102   Vincent Rubinetti        2021-11-10    8.0  hours_from_session_records
# 100        Steve Taylor        2021-11-09    0.5  hours_from_session_records
# 5     Vincent Rubinetti        2021-11-22    8.0  hours_from_session_records
# 41         Steve Taylor        2022-02-08    1.0  hours_from_session_records
# 144  Faisal Alquaddoomi        2022-04-20    1.0  hours_from_session_records
# ..                  ...               ...    ...                         ...
# 71   Faisal Alquaddoomi        2022-03-12    8.0  hours_from_session_records
# 30   Faisal Alquaddoomi        2022-02-09    3.0  hours_from_session_records
# 93   Faisal Alquaddoomi        2022-03-03    3.0  hours_from_session_records
# 94   Faisal Alquaddoomi        2022-03-04    3.0  hours_from_session_records
# 18         Steve Taylor        2022-02-02    5.0  hours_from_session_records
#
# [165 rows x 17 columns]

# %%
# merge the owner and session records
journal_task_df = pd.concat([owner_records_df, session_records_df])
journal_task_df
# Out:
#       MDC Task ID                                    Task Name  \
# 0      1912542060               Patch AWS (or remove entirely)
# 1      1957499412   Way Lab Grant Proposal Creation and Review
# 2      1957499412   Way Lab Grant Proposal Creation and Review
# 3      2003198974    "Word Lapse" Proposal Creation and Review
# 4      2064112158  monarch blue/green data migration, research
# ..            ...                                          ...
# 160  2625612513-2              review, merge preprint model PR
# 161  2660065499-1                     remove umap from backend
# 162  2660074814-1  investigate neighbor sorting + swagger docs
# 163  2660074814-1  investigate neighbor sorting + swagger docs
# 164  2688862846-1                                Finalize logo
#
#      MDC Project ID                                              Owner Status  \
# 0        2303324267               [{'id': 25810257, 'kind': 'person'}]   Done
# 1        1957293587  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 2        1957293587  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 3        1969468997               [{'id': 25810257, 'kind': 'person'}]   Done
# 4        1892630899               [{'id': 25815853, 'kind': 'person'}]   Done
# ..              ...                                                ...    ...
# 160      1969468997               [{'id': 25815853, 'kind': 'person'}]   Done
# 161      1969468997               [{'id': 25815853, 'kind': 'person'}]   Done
# 162      1969468997               [{'id': 25815853, 'kind': 'person'}]   Done
# 163      1969468997               [{'id': 25815853, 'kind': 'person'}]   Done
# 164      2334955423               [{'id': 25815860, 'kind': 'person'}]   Done
#
#                      Integration Message  \
# 0    Posted - 2022-04-27 16:44:52.850435
# 1    Posted - 2022-04-27 16:42:44.753809
# 2    Posted - 2022-04-27 16:42:44.753809
# 3    Posted - 2022-04-27 16:42:47.060917
# 4    Posted - 2022-04-27 16:47:42.940380
# ..                                   ...
# 160  Posted - 2022-06-02 08:19:57.195418
# 161  Posted - 2022-06-02 08:19:58.135173
# 162  Posted - 2022-06-02 08:19:59.075372
# 163  Posted - 2022-06-02 08:19:59.075372
# 164  Posted - 2022-06-02 08:20:00.006027
#
#                                             Task Notes  \
# 0    Time spent reviewing options; finally decided ...
# 1                                                 None
# 2                                                 None
# 3    200 hour proposal sent to Casey and David, 12/...
# 4                                                 None
# ..                                                 ...
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
# 164                                               None
#
#                                       Pull Request URL Issue URL  \
# 0                                                 None      None
# 1                                                 None      None
# 2                                                 None      None
# 3                                                 None      None
# 4                                                 None      None
# ..                                                 ...       ...
# 160                                               None      None
# 161                                               None      None
# 162                                               None      None
# 163                                               None      None
# 164  https://github.com/cytomining/pycytominer/pull...      None
#
#     Date Completed Extended Hours Reported Month-end Date  MDC Resource ID  \
# 0       2022-01-25           None                    None         25810257
# 1       2021-12-04           None                    None         25810257
# 2       2021-12-04           None                    None         25815853
# 3       2021-12-04           None                    None         25810257
# 4       2022-02-23           None                    None         25815853
# ..             ...            ...                     ...              ...
# 160     2022-05-11           None                    None         25815853
# 161     2022-05-11           None                    None         25815853
# 162     2022-05-23           None                    None         25815853
# 163     2022-05-23           None                    None         25815853
# 164     2022-05-18           None                    None         25815860
#
#           Resource Name  hours Session Completed      integration_state_rule
# 0          Steve Taylor    2.0        2022-01-25  hours_split_between_owners
# 1          Steve Taylor    2.0        2021-12-04  hours_split_between_owners
# 2    Faisal Alquaddoomi    2.0        2021-12-04  hours_split_between_owners
# 3          Steve Taylor    2.0        2021-12-04  hours_split_between_owners
# 4    Faisal Alquaddoomi   28.0        2022-02-23  hours_split_between_owners
# ..                  ...    ...               ...                         ...
# 160  Faisal Alquaddoomi    1.0        2022-05-04  hours_from_session_records
# 161  Faisal Alquaddoomi    0.5        2022-05-09  hours_from_session_records
# 162  Faisal Alquaddoomi    0.5        2022-05-09  hours_from_session_records
# 163  Faisal Alquaddoomi    0.5        2022-05-09  hours_from_session_records
# 164   Vincent Rubinetti    8.0        2022-05-16  hours_from_session_records
#
# [229 rows x 17 columns]

# %%
# convert to a datetime... a bit crude for filtering by year and month
date_completed = pd.to_datetime(journal_task_df["Date Completed"])

journal_task_df["task_end_year"] = pd.DatetimeIndex(date_completed).year
journal_task_df["task_end_month"] = pd.DatetimeIndex(date_completed).month

journal_task_df.head()
# Out:
#   MDC Task ID                                    Task Name  MDC Project ID  \
# 0  1912542060               Patch AWS (or remove entirely)      2303324267
# 1  1957499412   Way Lab Grant Proposal Creation and Review      1957293587
# 2  1957499412   Way Lab Grant Proposal Creation and Review      1957293587
# 3  2003198974    "Word Lapse" Proposal Creation and Review      1969468997
# 4  2064112158  monarch blue/green data migration, research      1892630899
#
#                                                Owner Status  \
# 0               [{'id': 25810257, 'kind': 'person'}]   Done
# 1  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 2  [{'id': 25810257, 'kind': 'person'}, {'id': 25...   Done
# 3               [{'id': 25810257, 'kind': 'person'}]   Done
# 4               [{'id': 25815853, 'kind': 'person'}]   Done
#
#                    Integration Message  \
# 0  Posted - 2022-04-27 16:44:52.850435
# 1  Posted - 2022-04-27 16:42:44.753809
# 2  Posted - 2022-04-27 16:42:44.753809
# 3  Posted - 2022-04-27 16:42:47.060917
# 4  Posted - 2022-04-27 16:47:42.940380
#
#                                           Task Notes Pull Request URL  \
# 0  Time spent reviewing options; finally decided ...             None
# 1                                               None             None
# 2                                               None             None
# 3  200 hour proposal sent to Casey and David, 12/...             None
# 4                                               None             None
#
#   Issue URL Date Completed Extended Hours Reported Month-end Date  \
# 0      None     2022-01-25           None                    None
# 1      None     2021-12-04           None                    None
# 2      None     2021-12-04           None                    None
# 3      None     2021-12-04           None                    None
# 4      None     2022-02-23           None                    None
#
#    MDC Resource ID       Resource Name  hours Session Completed  \
# 0         25810257        Steve Taylor    2.0        2022-01-25
# 1         25810257        Steve Taylor    2.0        2021-12-04
# 2         25815853  Faisal Alquaddoomi    2.0        2021-12-04
# 3         25810257        Steve Taylor    2.0        2021-12-04
# 4         25815853  Faisal Alquaddoomi   28.0        2022-02-23
#
#        integration_state_rule  task_end_year  task_end_month
# 0  hours_split_between_owners           2022               1
# 1  hours_split_between_owners           2021              12
# 2  hours_split_between_owners           2021              12
# 3  hours_split_between_owners           2021              12
# 4  hours_split_between_owners           2022               2

# %%
# only interested in this month's tasks
mask = (journal_task_df["task_end_year"] == year_for_report) & (
    journal_task_df["task_end_month"] == month_for_report
)
journal_task_df = journal_task_df.loc[mask].copy()
journal_task_df
# Out:
#    MDC Task ID                                          Task Name  \
# 9   2259600839                                    meetings and PR
# 10  2259614494  monarch ui check in meeting, figma sketch changes
#
#     MDC Project ID                                 Owner Status  \
# 9       1882442059  [{'id': 25815860, 'kind': 'person'}]   Done
# 10      1882442059  [{'id': 25815860, 'kind': 'person'}]   Done
#
#                     Integration Message  \
# 9   Posted - 2022-04-27 16:36:56.979918
# 10  Posted - 2022-04-27 16:36:59.369126
#
#                                    Task Notes  \
# 9   * imported from SmartSheets records [sjt]
# 10  * imported from SmartSheets records [sjt]
#
#                                      Pull Request URL Issue URL  \
# 9   https://github.com/monarch-initiative/monarch-...      None
# 10                                               None      None
#
#    Date Completed Extended Hours Reported Month-end Date  MDC Resource ID  \
# 9      2021-09-27           None                    None         25815860
# 10     2021-09-28           None                    None         25815860
#
#         Resource Name  hours Session Completed      integration_state_rule  \
# 9   Vincent Rubinetti   48.0        2021-09-27  hours_split_between_owners
# 10  Vincent Rubinetti    8.0        2021-09-28  hours_split_between_owners
#
#     task_end_year  task_end_month
# 9            2021               9
# 10           2021               9

# %% [markdown]
# Finally merge the tasks and projects together for a final task list.

# %%
# quick func for the next dataframe apply
def month_end_me(row):
    return month_end_date(row["task_end_year"], row["task_end_month"])

# %%
df = pd.merge(
    journal_task_df,
    account_projects_df,
    how="left",
    on="MDC Project ID",
)

# create a month-ending date column
month_end_dates = df.apply(month_end_me, axis=1)
if len(month_end_dates) > 0:
    df["Month Ending Date"] = month_end_dates
else:
    # going through the motions now so the rest of the notebook will run
    df["Month Ending Date"] = None

df.rename(
    columns={
        "monday_id_x": "MDC Task ID",
        "monday_id_y": "MDC Project ID",
        "Title_x": "Title",
        "Title_y": "Project Title",
        "Notes_x": "Notes",
        "Notes_y": "Project Notes",
        "hours": "Hours",
    },
    inplace=True,
)

df.drop(
    columns=["task_end_year", "task_end_month", "Owner"],
    inplace=True,
)

df
# Out:
#   MDC Task ID                                          Task Name  \
# 0  2259600839                                    meetings and PR
# 1  2259614494  monarch ui check in meeting, figma sketch changes
#
#    MDC Project ID Status                  Integration Message  \
# 0      1882442059   Done  Posted - 2022-04-27 16:36:56.979918
# 1      1882442059   Done  Posted - 2022-04-27 16:36:59.369126
#
#                                   Task Notes  \
# 0  * imported from SmartSheets records [sjt]
# 1  * imported from SmartSheets records [sjt]
#
#                                     Pull Request URL Issue URL Date Completed  \
# 0  https://github.com/monarch-initiative/monarch-...      None     2021-09-27
# 1                                               None      None     2021-09-28
#
#   Extended Hours  ...                       Project Name  Project Lifecycle  \
# 0           None  ...  TISLab: Monarch UI (3.0) Redesign             Closed
# 1           None  ...  TISLab: Monarch UI (3.0) Redesign             Closed
#
#   MDC Client ID  Grant Number  \
# 0    1882681714        213359
# 1    1882681714        213359
#
#                                        Project Notes Project Closed Date  \
# 0  Was managed and tracked via github and zenhub;...          2022-05-25
# 1  Was managed and tracked via github and zenhub;...          2022-05-25
#
#         Client Name Client Notes No Bill Month Ending Date
# 0  HealthAI: TISLab                False        2021-09-30
# 1  HealthAI: TISLab                False        2021-09-30
#
# [2 rows x 26 columns]

# %%
# only need billable
df = df.loc[df["No Bill"] == False]
df
# Out:
#   MDC Task ID                                          Task Name  \
# 0  2259600839                                    meetings and PR
# 1  2259614494  monarch ui check in meeting, figma sketch changes
#
#    MDC Project ID Status                  Integration Message  \
# 0      1882442059   Done  Posted - 2022-04-27 16:36:56.979918
# 1      1882442059   Done  Posted - 2022-04-27 16:36:59.369126
#
#                                   Task Notes  \
# 0  * imported from SmartSheets records [sjt]
# 1  * imported from SmartSheets records [sjt]
#
#                                     Pull Request URL Issue URL Date Completed  \
# 0  https://github.com/monarch-initiative/monarch-...      None     2021-09-27
# 1                                               None      None     2021-09-28
#
#   Extended Hours  ...                       Project Name  Project Lifecycle  \
# 0           None  ...  TISLab: Monarch UI (3.0) Redesign             Closed
# 1           None  ...  TISLab: Monarch UI (3.0) Redesign             Closed
#
#   MDC Client ID  Grant Number  \
# 0    1882681714        213359
# 1    1882681714        213359
#
#                                        Project Notes Project Closed Date  \
# 0  Was managed and tracked via github and zenhub;...          2022-05-25
# 1  Was managed and tracked via github and zenhub;...          2022-05-25
#
#         Client Name Client Notes No Bill Month Ending Date
# 0  HealthAI: TISLab                False        2021-09-30
# 1  HealthAI: TISLab                False        2021-09-30
#
# [2 rows x 26 columns]

# %%
# create a group by report and post to SE Project/Grant Time smartsheet
report_df = (
    df.groupby(["MDC Client ID", "MDC Project ID", "MDC Resource ID"])
    .agg(
        {
            "Client Name": "first",
            "Project Name": "first",
            "Resource Name": "first",
            "Hours": "sum",
            "Month Ending Date": "first",
            "Grant Number": "first",
            "No Bill": "first",
        }
    )
    .reset_index()
)
report_df["Prepared Date"] = prepared_date
report_df
# Out:
#    MDC Client ID  MDC Project ID  MDC Resource ID       Client Name  \
# 0     1882681714      1882442059         25815860  HealthAI: TISLab
#
#                         Project Name      Resource Name  Hours  \
# 0  TISLab: Monarch UI (3.0) Redesign  Vincent Rubinetti   56.0
#
#   Month Ending Date Grant Number  No Bill Prepared Date
# 0        2021-09-30       213359    False    2022-07-05

# %% [markdown]
# ## Build up the JSON object

# %%
# a list of all reports
reports = []

# %%
def get_client(clients_df, client_id):
    """
    Given the accounts/client DF, lookup an individual client.

    Return a dict
    """
    client_dict = clients_df.loc[clients_df["MDC Client ID"] == client_id].to_dict(
        "records"
    )[0]

    client = {
        "MDC Client ID": str(client_dict["MDC Client ID"]),
        "Client Name": client_dict["Client Name"],
        "No Bill": client_dict["No Bill"],
    }

    return client


# mini test
# get_client(accounts_df, 1882681714)

# %%
def get_project(projects_df, project_id):
    """
    Given a project DF, lookup project info by project ID

    Return a list of dict
    """

    projects = []

    project_dict = projects_df.loc[projects_df["MDC Project ID"] == project_id].to_dict(
        "records"
    )
    if len(project_dict) > 0:

        project = {
            "MDC Project ID": str(project_dict[0]["MDC Project ID"]),
            "Project Name": project_dict[0]["Project Name"],
            "Grant Proposal #": project_dict[0]["Grant Number"],
        }
        if project_dict[0].get("Project Notes"):
            project["Notes"] = project_dict[0]["Project Notes"]

    return project


# mini test
# get_project(projects_df, 1882442059)

# %%
def get_resource(users_df, resource_id):
    """
    Given the users DF, lookup resource by resource ID

    Return a list of dict
    """
    users_df["MDC Resource ID"] = users_df.index
    users_dict = users_df.loc[resource_id].to_dict()

    resource = None
    if len(users_dict) > 0:
        resource = {
            "MDC Resource ID": str(users_dict["MDC Resource ID"]),
            "Resource Name": users_dict["name"],
        }

    return resource


# mini test
# get_resource(users_df, 25815860)

# %%
def get_tasks(users_df, tasks_df, project_id, resource_id):
    """
    Given the final tasks DF, lookup resources and tasks by project ID and resource ID

    Return a list of dict
    """

    # keep a roster of resources and tasks

    task_dict = tasks_df.loc[
        (
            (tasks_df["MDC Project ID"] == project_id)
            & (tasks_df["MDC Resource ID"] == resource_id)
        )
    ].to_dict("records")

    resource = get_resource(users_df, resource_id)
    resource["Tasks"] = []

    for task in task_dict:

        # build up a task block
        task_dict = {
            "MDC Task ID": str(task["MDC Task ID"]),
            "Task Name": task["Task Name"],
            "Notes": task["Task Notes"],
            "Pull Request URL": task["Pull Request URL"],
            "Issue URL": task["Issue URL"],
            "Completed Hours": task["Hours"],
            "Task Complete Date": task["Date Completed"],
            "Integration Message": task["integration_state_rule"],
            "Session Complete Date": task["Session Completed"],
        }

        # append it to the list
        resource["Tasks"].append(task_dict)

    return resource


# mini test
pprint(get_tasks(users_df, df, 1882442059, 25815860))
# Out:
# {'MDC Resource ID': '25815860',
#  'Resource Name': 'Vincent Rubinetti',
#  'Tasks': [{'Completed Hours': 48.0,
#             'Integration Message': 'hours_split_between_owners',
#             'Issue URL': None,
#             'MDC Task ID': '2259600839',
#             'Notes': '* imported from SmartSheets records [sjt]',
#             'Pull Request URL': 'https://github.com/monarch-initiative/monarch-ui-new/pull/44',
#             'Session Complete Date': '2021-09-27',
#             'Task Complete Date': '2021-09-27',
#             'Task Name': 'meetings and PR'},
#            {'Completed Hours': 8.0,
#             'Integration Message': 'hours_split_between_owners',
#             'Issue URL': None,
#             'MDC Task ID': '2259614494',
#             'Notes': '* imported from SmartSheets records [sjt]',
#             'Pull Request URL': None,
#             'Session Complete Date': '2021-09-28',
#             'Task Complete Date': '2021-09-28',
#             'Task Name': 'monarch ui check in meeting, figma sketch changes'}]}

# %%
df.groupby(["MDC Project ID", "MDC Resource ID"]).agg(
    {"MDC Project ID": "first", "MDC Resource ID": "first"}
).to_dict("records")
# Out:
# [{'MDC Project ID': 1882442059, 'MDC Resource ID': 25815860}]

# %%
unique_clients_list = report_df["MDC Client ID"].unique().tolist()
unique_clients_list
# Out:
# [1882681714]

# %%
# we've come all this way (mostly because of MDC's subpar API), so we'll use report_df as our master
for client_id in unique_clients_list:

    report_dict = {
        "Month-ending Date": month_ending_date,
        "Report Prepared Date": prepared_date,
    }

    report_dict["Client"] = get_client(accounts_df, client_id)
    report_dict["Client"]["Projects"] = []

    unique_projects = (
        df.loc[df["MDC Client ID"] == client_id]["MDC Project ID"].unique().tolist()
    )

    for project_id in unique_projects:
        a_project = get_project(projects_df, project_id)

        unique_resources = (
            report_df.loc[
                (
                    (report_df["MDC Client ID"] == client_id)
                    & (report_df["MDC Project ID"] == project_id)
                )
            ]["MDC Resource ID"]
            .unique()
            .tolist()
        )

        for resource_id in unique_resources:

            # only add the Resources block if at least one shows up
            if not a_project.get("Resources"):
                a_project["Resources"] = []

            # get the project tasks block and append it to the project
            project_tasks = get_tasks(users_df, df, project_id, resource_id)
            a_project["Resources"].append(project_tasks)

        report_dict["Client"]["Projects"].append(a_project)

    reports.append(report_dict)

pprint(report_dict)
# Out:
# {'Client': {'Client Name': 'HealthAI: TISLab',
#             'MDC Client ID': '1882681714',
#             'No Bill': False,
#             'Projects': [{'Grant Proposal #': '213359',
#                           'MDC Project ID': '1882442059',
#                           'Notes': 'Was managed and tracked via github and '
#                                    'zenhub; backfilled from SmartSheet and '
#                                    'zenhub with best effort.',
#                           'Project Name': 'TISLab: Monarch UI (3.0) Redesign',
#                           'Resources': [{'MDC Resource ID': '25815860',
#                                          'Resource Name': 'Vincent Rubinetti',
#                                          'Tasks': [{'Completed Hours': 48.0,
#                                                     'Integration Message': 'hours_split_between_owners',
#                                                     'Issue URL': None,
#                                                     'MDC Task ID': '2259600839',
#                                                     'Notes': '* imported from '
#                                                              'SmartSheets '
#                                                              'records [sjt]',
#                                                     'Pull Request URL': 'https://github.com/monarch-initiative/monarch-ui-new/pull/44',
#                                                     'Session Complete Date': '2021-09-27',
#                                                     'Task Complete Date': '2021-09-27',
#                                                     'Task Name': 'meetings and '
#                                                                  'PR'},
#                                                    {'Completed Hours': 8.0,
#                                                     'Integration Message': 'hours_split_between_owners',
#                                                     'Issue URL': None,
#                                                     'MDC Task ID': '2259614494',
#                                                     'Notes': '* imported from '
#                                                              'SmartSheets '
#                                                              'records [sjt]',
#                                                     'Pull Request URL': None,
#                                                     'Session Complete Date': '2021-09-28',
#                                                     'Task Complete Date': '2021-09-28',
#                                                     'Task Name': 'monarch ui '
#                                                                  'check in '
#                                                                  'meeting, '
#                                                                  'figma sketch '
#                                                                  'changes'}]}]}]},
#  'Month-ending Date': '2021-09-30',
#  'Report Prepared Date': '2022-07-05'}

# %% [markdown]
# ## Schema validation

# %%
def validate_json(schema, json_data):

    # mostly from https://stackoverflow.com/questions/25145160/json-schema-ref-does-not-work-for-relative-path
    schemas = (json.load(open(source)) for source in Path("schema").iterdir())
    schema_store = {schema["$id"]: schema for schema in schemas}

    resolver = RefResolver.from_schema(schema, store=schema_store)

    try:
        result = validate(instance=json_data, schema=schema, resolver=resolver)
        return True, None
    except ValidationError as err:
        return False, err.message

# %%
# open schema
with open(os.path.join("schema", "effort_hours-report.json"), "r") as file:
    schema = json.load(file)

# %%
assert (True, None) == validate_json(schema, report_dict)

# %%
fail on purpose
# Out:
#   Input In [40]
#     fail on purpose
#          ^
# SyntaxError: invalid syntax
# ERROR:root:Cannot parse: 1:5: fail on purpose
# Traceback (most recent call last):
#   File "C:\Users\tastephe\AppData\Local\pypoetry\Cache\virtualenvs\mondaydotcom-notebooks-7FfDI7tN-py3.9\lib\site-packages\lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "C:\Users\tastephe\AppData\Local\pypoetry\Cache\virtualenvs\mondaydotcom-notebooks-7FfDI7tN-py3.9\lib\site-packages\lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "src\black\__init__.py", line 1163, in format_str
#   File "src\black\__init__.py", line 1173, in _format_str_once
#   File "src\black\parsing.py", line 128, in lib2to3_parse
# black.parsing.InvalidInput: Cannot parse: 1:5: fail on purpose

# %% [markdown]
# Now, Smartsheet's turn?

# %%
# smartsheet can have duplicate sheet names,
# so best not to rely on them
time_sheet_id = 3567675495475076
time_sheet = ss_client.Sheets.get_sheet(time_sheet_id)

# %%
# break down the cell IDs into a quick lookup box
cell_ids = {}
for column in time_sheet.columns:
    my_column = column.to_dict()
    cell_ids[my_column["title"]] = my_column["id"]
cell_ids

# %% [markdown]
# Add the records to Smartsheet

# %%
rows = []
for k, v in report_df.to_dict("index").items():

    row = ss_client.models.row.Row()

    row.cells.append(
        {"column_id": cell_ids["Client/Client"], "value": v["Client Name"]}
    )
    if v.get("Grant Number"):
        row.cells.append(
            {"column_id": cell_ids["Grant Proposal #"], "value": v["Grant Number"]}
        )
    row.cells.append(
        {"column_id": cell_ids["Project Title"], "value": v["Project Title"]}
    )
    row.cells.append(
        {"column_id": cell_ids["Month-end Date"], "value": v["Month Ending Date"]}
    )
    row.cells.append(
        {"column_id": cell_ids["Completed Hours"], "value": v["Hours"]}
    )
    row.cells.append({"column_id": cell_ids["Resource"], "value": v["Resource"]})
    row.cells.append({"column_id": cell_ids["MDC Client ID"], "value": v["MDC Client ID"]})
    row.cells.append({"column_id": cell_ids["MDC Project ID"], "value": v["MDC Project ID"]})

    row.to_bottom = True
    rows.append(row)

# %%
result = None
if rows and post_records:
    logger.info("Adding %s posted rows to SmartSheet", len(rows))
    result = ss_client.Sheets.add_rows(time_sheet_id, rows)

result

# %%
# get the row ids and create a Series
if result:
    my_list = []
    for row in result.to_dict()["data"]:
        my_list.append(row["id"])
        
    row_series = pd.Series(my_list, name="row_id", dtype=np.int64)
    row_series

    report_df = pd.concat([report_df, row_series], axis=1)

report_df

# %%
def filter_tasks(df, client, project, resource, month_end_date):
    """Get the journal tasks based on the details we'll send to smartsheet."""
    return df[
        (
            (df["Client Name"] == client)
            & (df["Project Title"] == project)
            & (df["Resource"] == resource)
            & (df["Month Ending Date"] == month_end_date)
        )
    ]

# %%
# create a dictionary to make attaching the files easier
new_dict = {}

# ensure all of the row_ids are filled in
if report_df['row_id'].all():

    for k, v in report_df.to_dict("index").items():
        row_id = v["row_id"]

        # add the filtered tasks to a list
        new_dict[row_id] = filter_tasks(
            df,
            v["Client Name"],
            v["Project Title"],
            v["Resource"],
            v["Month Ending Date"],
        )

# %%
if not os.path.exists("_cache"):
    os.mkdir("_cache")

# %%
# attach file to each record
for k, v in new_dict.items():
    filename = os.path.join("_cache", f"{k}.csv")

    # save file
    v.to_csv(filename, index=False)

    if post_records:
        with open(filename, "r") as f:
            ss_client.Attachments.attach_file_to_row(time_sheet_id, k, f)

# %%
if post_records:
    billable_posted = False
    for k, v in df.to_dict("index").items():
        if v["No Bill"]:
            result = conn.items.change_item_value(
                TASKS_BOARD_ID,
                v["MDC Task ID"],
                "text01",
                f"Posted - No Bill - {datetime.now()}",
            )
        else:
            result = conn.items.change_item_value(
                TASKS_BOARD_ID, v["MDC Task ID"], "text01", f"Posted - {datetime.now()}"
            )
            billable_posted = True

# %% [markdown]
# Delete any estimates

# %%
# delete the estimates only
result = None
# only do this if we had some monthly tasks to report
if billable_posted and len(report_df) > 0 and post_records:
    result = ss_client.Sheets.get_sheet(time_sheet_id, filter_id=5850658663360388)
    rows_to_delete = [x["id"] for x in result.to_dict()["rows"] if not x["filteredOut"]]
    if rows_to_delete:
        result = ss_client.Sheets.delete_rows(posted_tasks_id, rows_to_delete)
result
